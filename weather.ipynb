# %% [markdown]
# # <span style="color:orange"> Task 08: Notebook.<span>
# *By Laura Lyons*
# ***
#
# &#x26a0;&#xfe0f; **DISCLAIMER**
#
#   Microsoft Co-Pilot and ChatGPT were used to generate ideas for the content of the following notebook. That said, the notebook is mainly my own work, as I had to re-work the code generated to meet my own needs. (*The warning icon was sourced from [Stackoverflow](https://stackoverflow.com/questions/50544499/how-to-make-a-styled-markdown-admonition-box-in-a-github-gist)*)
#
# ## Table of contents
#
# [Introduction.](#1-introduction)
#
# [Weekly Tasks.](#2-weekly-tasks)
# - [Task 01- Create Directory Structure](#task-01---create-directory-structure)
# - [Task 02- Timestamps](#task-02---timestamps)
# - [Task 03- Formatting Timestamps](#task-03---formatting-timestamps)
# - [Task 04- Creating Timestamped Files](#task-04---creating-timestamped-files)
# - [Task 05- Download Today;s Weather Data](#task-05---download-todays-weather-data)
# - [Task 06- Timestamp the Data](#task-06---timestamp-the-data)
# - [Task 07- Write the Script](#task-07---write-the-script)
#
#
# ## Introduction
#
# This project was created to fufill an assessment requirement of Computer Infrastructure 24-25: 8645, as part of the H.Dip in Science in Data Analytics.
#
# Task 08 required that we create a notebook called *weather.ipynb* at the root of your repository. In this notebook, write a brief report explaining how you completed Tasks 1 to 7. Provide short descriptions of the commands used in each task and explain their role in completing the tasks.
#
# This repository is collection of my weekly tasks, including some additional guidance and instruction in how I excuted each task.
#
# ***

# %% [markdown]
# ## **Weekly Tasks**
#
# ***
#
# ## **Task 01** - Create Directory Structure
#
# ### **Assignment Instructions:**
#
# Using the command line, create a directory (that is, a folder) named data at the root of your repository. Inside data, create two subdirectories: timestamps and weather.
#
# ### **Associated Code:**
#
# ```ruby
# mkdir 'data'        # The 'mkdir' command was used to create folder 'data'
# ls                  # the 'l's' command was used to check that the folder was created correctly
#                     # I then used the 'cd' commend, to move into the data folder.
#                     # This is where i needed to created to sub-directories, timestamps and weather.
# cd data
# mkdir 'timestamps'
# mkdir 'weather'
# ls                  # to check that the folders were created.
# cd ..               # to move back into the parent folder 'data'.
#
# ```
# <div style="text-align: center;"> Table 01: A screen shoot of the task being completed, and its associated code.
#   <img src="images\task1.JPG" alt="Task01" style="border: 1px solid black;">
# </div>
#
# **My notes:**
# - For this excercise, I learned that files names are case sensitive. When up loading the images, i found they would display in VSCode but not in my GitHub respository. After much diliberation, it was due to syntax misalignment.
# - A border was added to all  images using the following code ' style="border: 1px solid black;"', retreived from CoPilot.
#
# <div style="text-align: center;">
#   <img src="images/copilot_border.JPG" alt="Task01">
# </div>
#
# ***

# %% [markdown]
# ## **Task 02** - Timestamps
#
# ### **Assignment Instructions:**
#
# Navigate to the data/timestamps directory. Use the date command to output the current date and time, appending the output to a file named now.txt. Make sure to use the >> operator to append (not overwrite) the file. Repeat this step ten times, then use the more command to verify that now.txt has the expected content.
#
# ### **Associated Code:**
#
# ```ruby
# date >> now.txt   # Output the current date & time, appending the output to a file named now.txt
# ls                # The 'ls' command was used to check that the above command delivered the desired output.
# cat now.txt       # The 'cat' command was used to output into the terminal, the contents of file 'now.txt'.
# date >> now.txt   # This command was run 10 additional times, to generate a more substantial data base.
# more now.txt      # The 'more' command was used to to view the content of 'now.txt', and verify its content.
# ```
#
# <div style="text-align: center;"> Table 02: A screen shoot of the task being completed, and its associated code.
#   <img src= "images\task2.JPG" alt="Task02" style="border: 1px solid black;">
# </div>
#
# **My notes:**
#
# 1. The date command is used to generate date and time in the format, day, month, date (time) hour, miute, second (UTC) year.
# 1. '>>' is a command used to append to the end of the file (a single '>' would have overwritten the file, rather then append)
# 1. If the >> was emittied from the, *date >> now.txt* command, the command would not work.
#
# ***

# %% [markdown]
# ## **Task 03** - Formatting Timestamps
#
# ### **Assignment Instructions:**
#
# Run the date command again, but this time format the output using YYYYmmdd_HHMMSS (e.g., 20261114_130003 for 1:00:03 PM on November 14, 2026). Refer to the date man page (using man date) for more formatting options. (Press q to exit the man page). Append the formatted output to a file named formatted.txt.
#
# ### **Associated Code:**
#
# ```ruby
# cd data/timestamps                  # This command was used to navigate into the 'timestamps' folder,
#                                     # which is where we want to add additional output.
# date +"%Y%m%d_%H%M%S" >> now.txt    # The newly formatted file name was then appended to 'now.txt'.
# ls                                  # The 'ls' command was used to verify that the command had run correctly.
#                                     # We can clearly see the new file name saved in Table03a.
# man date                            # The 'man' command was used to navigate to the 'help' page for the 'date'
#                                     # command, were we would see various formatting options available for the
#                                     # 'date' command.
#                                     #'q' was used to exit the 'man date' page.
# date +"%Y%m%d_%H%M%S" >> formatted.txt # Append the formatted output to a file named formatted.txt.
# ```
# <div style="text-align: center;"> Table 03a: A screen shoot of the task being completed, and its associated code.
#   <img src="images\task3a.JPG" alt="Task03a" style="border: 1px solid black;">
# </div>
#
# <div style="text-align: center;"> Table 03b: A screen shoot of the 'man date' page'.
#   <img src="images\task3b.JPG" alt="Task03b" style="border: 1px solid black;">
# </div>
#
# **My notes:**
# 1. The following datetime format "%Y%m%d_%H%M%S", will out put a timestamp with the format, year, month, day _ hour, minute, second'.
# 1. It is essential that there is no space between '+' and '"%Y%m%d_%H%M%S"', otherwise the command will not be recognised.
# 1. Is it best practice to use this format, with the year first, as it will avoid ording issues, where by files could potentially be organised by the first day of each month, rather than chronologically.
#
# ***

# %% [markdown]
# ## **Task 04** - Creating Timestamped Files
#
# ### **Assignment Instructions:**
#
# Use the touch command to create an empty file with a name in the YYYYmmdd_HHMMSS.txt format. You can achieve this by embedding your date command in backticks ` into the touch command. You should no longer use redirection (>>) in this step.
#
# ### **Associated Code:**
#
# ```ruby
# cd data/timestamps                  # This command was used to navigate into the 'timestamps' folder, within the 'data' directory.
# touch `date +"%Y%m%d_%H%M%S.txt"`  # The 'touch' command was used to create an empty file with a name in the YYYYmmdd_HHMMSS.txt format.
# ls                                  # As always, the 'ls' command was used to check that the commands had worked correctly,
#                                     # That the file was created and located in the correct location (incorrectly located files were removed.)
#
# ```
#
# <div style="text-align: center;"> Table 04: A screen shoot of the task being completed, and its associated code.
#   <img src="images/task4.JPG" alt="Task04" style="border: 1px solid black;">
# </div>
#
# **My notes:**
# 1. I researched the difference between the 'touch' and 'mkdir' commands
# (Reference: https://superuser.com/questions/1340868/ubuntu-command-line-mkdir-vs-touch-creating-doc-file).
# 1. The 'touch' command is used primarily to create an empty file, or to update a timestpand of an existaing file.
# 1. The 'mkdir' command is used to create a new directory (folder).
# 1. Originially i used the code "touch $(date +"%Y%m%d_%H%M%S") .txt" is an alternative to using back ticks. $() can also be used for command substituation, to allow you to capture the ouput of a command as use it as an argument in another.
# (Reference: https://www.bing.com/search?pglt=297&q=%24()+instead+of+back+ticks&cvid=ac2081284556415bafb54cc703476594&gs_lcrp=EgRlZGdlKgYIABBFGDkyBggAEEUYOTIGCAEQRRg80gEHMTU3ajBqMagCCLACAQ&FORM=ANNTA1&PC=U531)
#
# ***

# %% [markdown]
# ## **Task 05** - Download Todays Weather Data
#
# ### **Assignment Instructions:**
#
# Change to the data/weather directory. Download the latest weather data for the Athenry weather station from Met Eireann using wget. Use the -O filename option to save the file as weather.json. The data can be found at this URL:
# <https://prodapi.metweb.ie/observations/athenry/today>.
#
# ### **Associated Code:**
#
# ```ruby
# sudo apt install wget   # As this was my first time using the app, 'wget', i will need to download the module,
#                         # using the 'sudo' command.
# cd data
# cd weather              # I then navigated into the 'data/weather' folder using the 'cd' command.
# wget -O weather.json https://prodapi.metweb.ie/observations/athenry/today.
#                         # the'wget' command was used to download the data from the web address.
#                         # '-0' is a shell re-direction, used to allow you to choose the filename 'weather.json'.
#                         # Retrieved from 'man wget'
#                         # Finally the web address of the data was added to the command.
# ls                      # The 'ls' command was used to check that the commands had worked correctly,
#                         # That the file was created in the correct location.
# ```
#
# <div style="text-align: center;"> Table 05: A screen shoot of the task being completed, and its associated code.
#   <img src="images/task5.JPG" alt="Task05" style="border: 1px solid black;">
# </div>
#
# **My notes:**
# 1. Remember to use a capital 'O' in the 'wget' command and a small 'o' has a different meaning.
#
# ***

# %% [markdown]
# ## **Task 06** - Timestamp the Data
#
# ### **Assignment Instructions:**
#
# Modify the command from Task 5 to save the downloaded file with a timestamped name in the format YYYYmmdd_HHMMSS.json.
#
# ### **Associated Code:**
#
# ```ruby
# cd data/weather         # I navigated into the 'data/weather' folder using the 'cd' command.
# wget -0 `date +"%Y%m%d_%H%M%S.json"`https://prodapi.metweb.ie/observations/athenry/today.
#                         # the'wget' command was used to download the data from the web address.
#                         # '-0' is a shell re-direction, used to allow you to choose the filename '%Y%m%d_%H%M%S.json'.
#                         # Finally the web address of the data was added to the command.
# ls                      # The 'ls' command was used to check that the commands had worked correctly,
#                         # That the file was created in the correct location.
# ```
#
# <div style="text-align: center;"> Table 06: A screen shoot of the task being completed, and its associated code.
#   <img src="images/task6.JPG" alt="Task06" style="border: 1px solid black;">
# </div>
#
# **My notes:**
# - I built ont he code from Task 05 to complete Task 06.
# - The differrence being, that the file name would now be constructed using the current timestamp.
# - This would be useful when you need to down load a number of iteraltions of data, at different times.
# - This filename formatt will also be usful when organising data files and it will ensure the data is store chronologically.
# ***

# %% [markdown]
# ## **Task 07** - Write the Script
#
# ### **Assignment Instructions:**
#
# Write a bash script called weather.sh in the root of your repository. This script should automate the process from Task 6, saving the weather data to the data/weather directory. Make the script executable and test it by running it.
#
# ### **Associated Code:**
#
# 1. The first part of the task was to create a bash script called weather.sh in the root of your repository.
#
# ```ruby
# cd ..                   # the 'cd ..' command was used twice to navigate to the root of the repository
# cd ..
# mkdir 'weather.sh'      # The 'mkdir' command was used to create folder 'weather.sh'.
# ```
#
# ***
#
# 2. This is the code (and associated explaination) that was used in the bash script.
#
# ```ruby
# #! /bin/bash            # This command indicates that the file is a bash file.
# date                    # This will out put the current date, letting us know when the task began.
# echo "Downloading the weather data" # The 'echo' command is similar to the 'priunt' command, in that it will out put what ever command is inbetween the commas.
# wget -0 `date +"%Y%m%d_%H%M%S.json"`https://prodapi.metweb.ie/observations/athenry/today.
#                         # This is the command that we formulated in Task06.
# echo 'Weather download complete'    # This will be printed in the terminal when the above command is complete.
# date                    # This will out put the current date, letting us know when the task was complete.
# ```
#
# <div style="text-align: center;"> Table 07b: A screenshot of the 'bash' script created.
#   <img src="images/task7aa.JPG" alt="Task07aa" style="border: 1px solid black;">
# </div>
#
# ***
#
# 3. Once the bash script was complete; we needed to modify to ensure that it could be run by the user.
#
# ```ruby
# ls -al                  # This command was used to view, in detail, what files were present in the root of the repository.
#                         # From this, we ca see that 'weather.sh' is in a 'write' only format, and is not excutable by the user, ie., '-rw-rw-rw-'.
# chmod u+x ./weather.sh  # 'chmod', is the command to change mode.
#                         # 'u+x', allows the user to now excute the file.
#                         # './weather.sh', is the file that we want these commands to be applied to.
# ls -al                  # Now we can see that 'weather.sh' is user excutable ie.,'-rwxrw-rw-'.
# ./weather.sh            # Now, when we want to download the
# ```
#
# <div style="text-align: center;"> Table 07b: A screen shoot of the task being completed, and its associated code.
#   <img src="images/task7a.JPG" alt="Task07a" style="border: 1px solid black;">
# </div>
#
# <div style="text-align: center;"> Table 07c: A screen shoot of the tasking being run, using './weather.sh' command.
#   <img src="images/task7b.JPG" alt="Task07b" style="border: 1px solid black;">
# </div>
#
#
# ***
#
# 4. After the inital run, I noted that the data was not being sent to my data folder, but directly into the root of my repository. It is not good practice to keep data files in the root of your repsository, so i modified the command, to re-direct the downloaded data into my 'data/weather' directories.
#
# ```ruby
# wget -0 data/weather/ `date +"%Y%m%d_%H%M%S.json"`https://prodapi.metweb.ie/observations/athenry/today.
#                         # I add the location of where i wanted the generated data to be stored 'data/weather/.
# ```
#
# <div style="text-align: center;"> Table 07d: A screen shoot of the tasking buting run & storing to the correct directory.
#   <img src="images/task7a3.JPG" alt="Task07a3" style="border: 1px solid black;">
# </div>
#
# ***
#
# **My notes:**
# - The benefits of putting numerous commands into a folder, ios that they can all be run together, under a single command.
# - The script used to centre allign the images was retrieved using Microsoft- CoPilot.
# <div style="text-align: center;">
#   <img src="images/copilot.JPG" alt="image.png">
# </div>
#
#
# ***

# %% [markdown]
# ## **Task 09** - Pandas
#
# ### **Assignment Instructions: 09**
#
# In your weather.ipynb notebook, use the pandas function read_json() to load in any one of the weather data files you have downloaded with your script. Examine and summarize the data. Use the information provided data.gov.ie to write a short explanation of what the data set contains.
#
# ***

# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the data.
#
# ***
#
# - The data needs to be imported using a specific filename format, to make data analysis easier.
# - Using the following format will ensure that the data is store chronololigically rather than numerically.
# ``` ruby
# date +"%Y%m%d_%H%M%S.json"
# ```

# %%
# Dowloading the data from a previously downloaded file
df = pd.read_json('data/weather/20241123_153808_athenry.json')

# Originally I was haaving issues getting the data to load as I read in the data as 'data\weather\20241123_153808_athenry.json', 
# which was causing issues with the backslashes. 
# I had to change the file path to 'data/weather/20241123_153808_athenry.json' to get the data to load correctly.

# %% [markdown]
# ### Analyising the data.
#
# ***

# %%
# Lets look at the first 3 rows of the data.
print('Table 1: An over of the weather data, Saturday 23rd of November 2024')
df
# Out:
# Table 1: An over of the weather data, Saturday 23rd of November 2024
#        name  temperature symbol  weatherDescription                 text  \
# 0   Athenry            3    46n         Light rain         "Light rain "
# 1   Athenry            4    09n                Rain     "Moderate rain "
# 2   Athenry            5    46n         Light rain         "Light rain "
# 3   Athenry            6    09n                Rain     "Moderate rain "
# 4   Athenry           10    09n                Rain     "Moderate rain "
# 5   Athenry           12    09n                Rain     "Moderate rain "
# 6   Athenry           12    46n         Light rain         "Light rain "
# 7   Athenry           13    09n                Rain     "Moderate rain "
# 8   Athenry           13    46d         Light rain   "Moderate Drizzle "
# 9   Athenry           13    46d         Light rain     "Recent Drizzle "
# 10  Athenry           14    40d  Light rain showers        "Recent Rain"
# ...

# %%
# Lets inspect the variable types.
print('Table 2: The types of data recorded in each of the variables, of the weather data, Saturday 23rd of November 2024.')
df.dtypes
# Out:
# Table 2: The types of data recorded in each of the variables, of the weather data, Saturday 23rd of November 2024.
# name                             object
# temperature                       int64
# symbol                           object
# weatherDescription               object
# text                             object
# windSpeed                         int64
# windGust                         object
# cardinalWindDirection            object
# windDirection                     int64
# humidity                          int64
# rainfall                        float64
# pressure                          int64
# dayName                          object
# date                     datetime64[ns]
# reportTime                       object
# dtype: object

# %%
# Lets also take a look at a few summary statistics of the data.
print('Table 3: A summary of the weather data, Saturday 23rd of November 2024.')
df.describe()
# Out:
# Table 2: A summary of the weather data, Saturday 23rd of November 2024.
#        temperature  windSpeed  windDirection  humidity   rainfall  pressure  \
# count     16.00000  16.000000      16.000000   16.0000  16.000000   16.0000
# mean      11.06250  26.062500     188.437500   90.8125   1.888125  982.7500
# min        3.00000  19.000000     135.000000   83.0000   0.000000  978.0000
# 25%        9.00000  23.500000     168.750000   85.7500   0.007500  979.0000
# 50%       13.00000  28.000000     180.000000   92.5000   1.850000  980.0000
# 75%       14.00000  28.500000     225.000000   95.0000   3.175000  983.5000
# max       15.00000  31.000000     225.000000   97.0000   4.900000  998.0000
# std        4.13874   4.234285      37.537481    4.7500   1.851483    5.9048
#
#                       date
# count                   16
# mean   2024-11-23 00:00:00
# min    2024-11-23 00:00:00
# 25%    2024-11-23 00:00:00
# 50%    2024-11-23 00:00:00
# 75%    2024-11-23 00:00:00
# ...

# %%
# Lets check if there are correlations between the measured variables.
# Specify the columns to run the correlation on
columns_of_interest = ['temperature', 'windSpeed', 'humidity', 'rainfall', 'pressure']
correlation_matrix = df[columns_of_interest].corr()
correlation_matrix
# Out:
#              temperature  windSpeed  humidity  rainfall  pressure
# temperature     1.000000  -0.696402 -0.392738 -0.566791 -0.929547
# windSpeed      -0.696402   1.000000  0.544221  0.631247  0.627268
# humidity       -0.392738   0.544221  1.000000  0.685913  0.216892
# rainfall       -0.566791   0.631247  0.685913  1.000000  0.347720
# pressure       -0.929547   0.627268  0.216892  0.347720  1.000000

# %%
# CoPilot was used to help generate this figure. 
# A number of changes had to be made to the generated code, as it was not working as intended.
# Firstly, it plotted the variable 'date' rather than 'reportTime'.
# Secondly, the code was not present in the figure setting that i wanted to use, so i modified the code to present on a single figure. 

# Create a figure and axis
fig, ax = plt.subplots(5, 1, figsize=(12, 8))

# Plot temperature
ax[0,0].plot(df.index, df['temperature'], color='tab:red', label='Temperature (°C)')
ax[0,0].set_xlabel('reportTime')
ax[0,0].set_ylabel('Temperature (°C)', color='tab:red')
ax[0,0].tick_params(axis='y', labelcolor='tab:red')
ax[0,0].set_title('Temperature Over Time')

# Plot wind speed
ax[0,1].plot(df.index, df['windSpeed'], color='tab:blue', label='Wind Speed (kt)')
ax[0,1].set_xlabel('reportTime')
ax[0,1].set_ylabel('Wind Speed (kt)', color='tab:blue')
ax[0,1].tick_params(axis='y', labelcolor='tab:blue')
ax[0,1].set_title('Wind Speed Over Time')

# Plot humidity
ax[0,2].plot(df.index, df['humidity'], color='tab:green', label='Humidity (%)')
ax[0,2].set_xlabel('reportTime')
ax[0,2].set_ylabel('Humidity (%)', color='tab:green')
ax[0,2].tick_params(axis='y', labelcolor='tab:green')
ax[0,2].set_title('Humidity Over Time')

# Plot rainfall
ax[1,0].plot(df.index, df['rainfall'], color='tab:purple', label='Rainfall (mm)')
ax[1,0].set_xlabel('reportTime')
ax[1,0].set_ylabel('Rainfall (mm)', color='tab:purple')
ax[1,0].tick_params(axis='y', labelcolor='tab:purple')
ax[1,0].set_title('Rainfall Over Time')

# Plot pressure
ax[1,1].plot(df.index, df['pressure'], color='tab:orange', label='Pressure (mbar)')
ax[1,1].set_xlabel('reportTime')
ax[1,1].set_ylabel('Pressure (mbar)', color='tab:orange')
ax[1,1].tick_params(axis='y', labelcolor='tab:orange')
ax[1,1].set_title('Pressure Over Time')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and axis
fig, ax = plt.subplots(5, 1, figsize=(12, 8))

# Plot temperature
ax[0].plot(df.index, df['temperature'], color='tab:red', label='Temperature (°C)')
ax[0].set_xlabel('reportTime')
ax[0].set_ylabel('Temperature (°C)', color='tab:red')
ax[0].tick_params(axis='y', labelcolor='tab:red')
ax[0].set_title('Temperature Over Time')

# Plot wind speed
ax[1].plot(df.index, df['windSpeed'], color='tab:blue', label='Wind Speed (kt)')
ax[1].set_xlabel('reportTime')
ax[1].set_ylabel('Wind Speed (kt)', color='tab:blue')
ax[1].tick_params(axis='y', labelcolor='tab:blue')
ax[1].set_title('Wind Speed Over Time')

# Plot humidity
ax[2].plot(df.index, df['humidity'], color='tab:green', label='Humidity (%)')
ax[2].set_xlabel('reportTime')
ax[2].set_ylabel('Humidity (%)', color='tab:green')
ax[2].tick_params(axis='y', labelcolor='tab:green')
ax[2].set_title('Humidity Over Time')

# Plot rainfall
ax[3].plot(df.index, df['rainfall'], color='tab:purple', label='Rainfall (mm)')
ax[3].set_xlabel('reportTime')
ax[3].set_ylabel('Rainfall (mm)', color='tab:purple')
ax[3].tick_params(axis='y', labelcolor='tab:purple')
ax[3].set_title('Rainfall Over Time')

# Plot pressure
ax[4].plot(df.index, df['pressure'], color='tab:orange', label='Pressure (mbar)')
ax[4].set_xlabel('reportTime')
ax[4].set_ylabel('Pressure (mbar)', color='tab:orange')
ax[4].tick_params(axis='y', labelcolor='tab:orange')
ax[4].set_title('Pressure Over Time')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and axis
fig, ax = plt.subplots(5, 1, figsize=(12, 8))

# Plot temperature
ax[0].plot(df.index, df['temperature'], color='tab:red', label='Temperature (°C)')
ax[0].set_xlabel('reportTime')
ax[0].set_ylabel('Temperature (°C)', color='tab:red')
ax[0].tick_params(axis='y', labelcolor='tab:red')
ax[0].set_title('Temperature Over Time')

# Plot wind speed
ax[1].plot(df.index, df['windSpeed'], color='tab:blue', label='Wind Speed (kt)')
ax[1].set_xlabel('reportTime')
ax[1].set_ylabel('Wind Speed (kt)', color='tab:blue')
ax[1].tick_params(axis='y', labelcolor='tab:blue')
ax[1].set_title('Wind Speed Over Time')

# Plot humidity
ax[2].plot(df.index, df['humidity'], color='tab:green', label='Humidity (%)')
ax[2].set_xlabel('reportTime')
ax[2].set_ylabel('Humidity (%)', color='tab:green')
ax[2].tick_params(axis='y', labelcolor='tab:green')
ax[2].set_title('Humidity Over Time')

# Plot rainfall
ax[3].plot(df.index, df['rainfall'], color='tab:purple', label='Rainfall (mm)')
ax[3].set_xlabel('reportTime')
ax[3].set_ylabel('Rainfall (mm)', color='tab:purple')
ax[3].tick_params(axis='y', labelcolor='tab:purple')
ax[3].set_title('Rainfall Over Time')

# Plot pressure
ax[4].plot(df.index, df['pressure'], color='tab:orange', label='Pressure (mbar)')
ax[4].set_xlabel('reportTime')
ax[4].set_ylabel('Pressure (mbar)', color='tab:orange')
ax[4].tick_params(axis='y', labelcolor='tab:orange')
ax[4].set_title('Pressure Over Time')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Results
#
# ***
#
# - The data contains a list of hourly data, for the the day upon which is was retreived. The file is updated hourly and the times are local times. The data was retieved from [data.gov.ie](https://prodapi.metweb.ie/observations/athenry/today), and was retreived on Saturday 23rd of November 2024.
# - From the above analysis we can see that there is 15 variables and 16 rows of data, all recorded on Saturday 23rd of November 2024 (Table: 1). These variables include:
#     1. Name (the location of the weather station, for this instance we use Athenry)
#     2. Dry bulb temperature in 0<sup>o</sup>C
#     3. Weather description,
#     4. Windspeed (kt),
#     5. Cardinal Wind Direction,
#     6. Relative Humidity (%),
#     7. Rainfall (mm).
#     8. msl Pressure (mbar),
#     9. Day of the week.
#     10. Date,
#     11. Time of observation.
#
# From table 3 we can see that for Saturday 23rd of November 2024,
# - The data was collected between 00.00 and 15.00 (Table 1). No data was collected between 16.00 and 23.00 inclusive.
# - the mean drub bulb temperature was 11.06 0 <sup>o</sup>C, the max was 15.00 <sup>o</sup>C and the minimum was 3.00 <sup>o</sup>C.
# - the mean wind speed was 26.06 kt, the maximum was 31.00 kt and the minimum was 19.0 kt.

# %% [markdown]
# ## End
